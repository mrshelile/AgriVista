# %%
import pandas as pd
import numpy as np

# Define the crops and districts
crops = [
    "Cabbage", "Spinach", "Carrots", "Onions", "Tomatoes", "Lettuce", "Broccoli",
    "Cauliflower", "Peppers", "Eggplant", "Zucchini", "Pumpkin", "Squash", "Radishes",
    "Daikon Radish", "Turnips", "Kale", "Swiss Chard", "Celery", "Leeks", "Artichokes",
    "Asparagus", "Bok Choy", "Brussels Sprouts", "Collard Greens", "Endive", "Fennel",
    "Garlic", "Horseradish", "Jicama", "Kohlrabi", "Okra", "Parsnips", "Rutabaga",
    "Scallions", "Shallots", "Snow Peas", "Snap Peas", "Watercress", "Arugula",
    "Mustard Greens", "Purslane", "Sorrel", "Tatsoi", "Mizuna", "Mibuna", "Celtuce",
    "Chinese Broccoli", "Chinese Cabbage", "Napa Cabbage", "Amaranth Greens", "Malabar Spinach",
    "New Zealand Spinach", "Water Spinach", "Sweet Corn", "Bulgur", "Maize", "Sorghum",
    "Wheat", "Barley", "Millet", "Oats", "Rye", "Triticale", "Quinoa", "Amaranth",
    "Buckwheat", "Spelt", "Teff", "Fonio", "Kañiwa", "Job’s Tears", "Wild Rice",
    "Einkorn", "Green Luobo", "Beans", "Peas", "Lentils", "Chickpeas", "Soybeans",
    "Cowpeas", "Pigeon Peas", "Lupins", "Mung Beans", "Black Beans", "Kidney Beans",
    "Navy Beans", "Pinto Beans", "Adzuki Beans", "Fava Beans", "Lima Beans", 
    "Black-eyed Peas", "Lentils (Red, Green, Brown)", "Winged Beans", "Hyacinth Beans",
    "Velvet Beans", "Sword Beans", "Tepary Beans", "White Icicle Radish", "Basil", 
    "Parsley", "Cilantro", "Mint", "Thyme", "Rosemary", "Sage", "Oregano", 
    "Dill", "Chives", "Tarragon", "Marjoram", "Lemon Balm", "Lovage", "Bay Leaves",
    "Chamomile", "Echinacea", "Lavender", "Peppermint", "Spearmint", "Catnip", 
    "Feverfew", "Hyssop", "Lemon Verbena", "Stevia", "Sakurajima Radish", 
    "Potatoes", "Sweet Potatoes", "Yams", "Cassava", "Taro", "Jerusalem Artichokes", 
    "Ginger", "Turmeric", "Arrowroot", "Salsify", "Oca", "Ulluco", "Mashua", 
    "Yacon", "Maca", "Purple Plum", "Sunflowers", "Canola", "Flax", "Sesame", 
    "Safflower", "Cotton", "Tobacco", "Sugarcane", "Alfalfa", "Clover", "Hemp", 
    "Jute", "Kenaf", "Ramie", "Sisal", "Bamboo", "Bamboo Shoots", "Aloe Vera", 
    "Agave", "Cactus Pear", "Quinoa", "Chia", "Poppy", "Saffron", "Vanilla"
]

districts = ["District A", "District B", "District C", "District D", "District E"]

# Define the date range
date_range = pd.date_range(start='2022-01-01', end='2024-12-01', freq='MS')

# Create a list to store each entry
data = []

# Loop through each crop, district, and date to generate the data
for crop in crops:
    for district in districts:
        for date in date_range:
            entry = {
                'Date': date,
                'Crop': crop,
                'District': district,
                'Market_Price': np.random.uniform(1, 10),  # Sample prices
                'Production_Cost': np.random.uniform(0.5, 7),  # Sample production costs
                'Supply_vs_Demand_Ratio': np.random.uniform(0.5, 2)  # Sample ratios
            }
            data.append(entry)

# Create the DataFrame from the list of entries
df = pd.DataFrame(data)

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#         Date     Crop    District  Market_Price  Production_Cost  \
# 0 2022-01-01  Cabbage  District A      8.171196         5.407123
# 1 2022-02-01  Cabbage  District A      6.035950         5.232727
# 2 2022-03-01  Cabbage  District A      8.003495         5.452338
# 3 2022-04-01  Cabbage  District A      7.816954         1.330659
# 4 2022-05-01  Cabbage  District A      6.870615         4.109135
#
#    Supply_vs_Demand_Ratio
# 0                0.990140
# 1                1.325903
# 2                1.111372
# 3                1.261722
# 4                1.364903

# %%
import pandas as pd
import numpy as np

# Define the crops and districts
crops = [
    "Cabbage", "Spinach", "Carrots", "Onions", "Tomatoes", "Lettuce", "Broccoli",
    "Cauliflower", "Peppers", "Eggplant", "Zucchini", "Pumpkin", "Squash", "Radishes",
    "Daikon Radish", "Turnips", "Kale", "Swiss Chard", "Celery", "Leeks", "Artichokes",
    "Asparagus", "Bok Choy", "Brussels Sprouts", "Collard Greens", "Endive", "Fennel",
    "Garlic", "Horseradish", "Jicama", "Kohlrabi", "Okra", "Parsnips", "Rutabaga",
    "Scallions", "Shallots", "Snow Peas", "Snap Peas", "Watercress", "Arugula",
    "Mustard Greens", "Purslane", "Sorrel", "Tatsoi", "Mizuna", "Mibuna", "Celtuce",
    "Chinese Broccoli", "Chinese Cabbage", "Napa Cabbage", "Amaranth Greens", "Malabar Spinach",
    "New Zealand Spinach", "Water Spinach", "Sweet Corn", "Bulgur", "Maize", "Sorghum",
    "Wheat", "Barley", "Millet", "Oats", "Rye", "Triticale", "Quinoa", "Amaranth",
    "Buckwheat", "Spelt", "Teff", "Fonio", "Kañiwa", "Job’s Tears", "Wild Rice",
    "Einkorn", "Green Luobo", "Beans", "Peas", "Lentils", "Chickpeas", "Soybeans",
    "Cowpeas", "Pigeon Peas", "Lupins", "Mung Beans", "Black Beans", "Kidney Beans",
    "Navy Beans", "Pinto Beans", "Adzuki Beans", "Fava Beans", "Lima Beans", 
    "Black-eyed Peas", "Lentils (Red, Green, Brown)", "Winged Beans", "Hyacinth Beans",
    "Velvet Beans", "Sword Beans", "Tepary Beans", "White Icicle Radish", "Basil", 
    "Parsley", "Cilantro", "Mint", "Thyme", "Rosemary", "Sage", "Oregano", 
    "Dill", "Chives", "Tarragon", "Marjoram", "Lemon Balm", "Lovage", "Bay Leaves",
    "Chamomile", "Echinacea", "Lavender", "Peppermint", "Spearmint", "Catnip", 
    "Feverfew", "Hyssop", "Lemon Verbena", "Stevia", "Sakurajima Radish", 
    "Potatoes", "Sweet Potatoes", "Yams", "Cassava", "Taro", "Jerusalem Artichokes", 
    "Ginger", "Turmeric", "Arrowroot", "Salsify", "Oca", "Ulluco", "Mashua", 
    "Yacon", "Maca", "Purple Plum", "Sunflowers", "Canola", "Flax", "Sesame", 
    "Safflower", "Cotton", "Tobacco", "Sugarcane", "Alfalfa", "Clover", "Hemp", 
    "Jute", "Kenaf", "Ramie", "Sisal", "Bamboo", "Bamboo Shoots", "Aloe Vera", 
    "Agave", "Cactus Pear", "Quinoa", "Chia", "Poppy", "Saffron", "Vanilla"
]

districts = ["Maseru", "Thaba Tseka", "Quthing",
             "Mohale suek", "Leribe","Berea","Mafeteng",
             "Qacha","Butha Bothe"]

# Define the date range
date_range = pd.date_range(start='2022-01-01', end='2024-12-01', freq='MS')

# Create a list to store each entry
data = []

# Set realistic market price and production cost ranges
market_price_range = (10, 30)  # Maluti
production_cost_range = (3, 10)  # Maluti

# Loop through each crop, district, and date to generate the data
for crop in crops:
    for district in districts:
        for date in date_range:
            # Generate realistic market price and production cost
            market_price = np.random.uniform(*market_price_range)
            production_cost = np.random.uniform(*production_cost_range)
            
            # Calculate Gross Profit Margin (GPM)
            gpm = (market_price - production_cost) / market_price * 100
            
            entry = {
                'Date': date,
                'Crop': crop,
                'District': district,
                'Market_Price': round(market_price, 2),  # Round to 2 decimal places
                'Production_Cost': round(production_cost, 2),  # Round to 2 decimal places
                'Gross_Profit_Margin': round(gpm, 2)  # Round to 2 decimal places
            }
            data.append(entry)

# Create the DataFrame from the list of entries
df = pd.DataFrame(data)

# Display the first few rows of the DataFrame
print(df.head(10))
# Out:
#         Date     Crop District  Market_Price  Production_Cost  \
# 0 2022-01-01  Cabbage   Maseru         16.49             7.36
# 1 2022-02-01  Cabbage   Maseru         11.35             3.70
# 2 2022-03-01  Cabbage   Maseru         22.27             5.11
# 3 2022-04-01  Cabbage   Maseru         27.90             4.13
# 4 2022-05-01  Cabbage   Maseru         14.63             3.20
# 5 2022-06-01  Cabbage   Maseru         19.23             4.38
# 6 2022-07-01  Cabbage   Maseru         15.20             4.11
# 7 2022-08-01  Cabbage   Maseru         20.92             9.16
# 8 2022-09-01  Cabbage   Maseru         18.51             8.04
# 9 2022-10-01  Cabbage   Maseru         20.56             7.98
#
#    Gross_Profit_Margin
# 0                55.36
# 1                67.42
# 2                77.05
# 3                85.20
# 4                78.11
# 5                77.25
# 6                72.94
# 7                56.23
# 8                56.55
# 9                61.17

# %%
df.to_csv("market.csv")
